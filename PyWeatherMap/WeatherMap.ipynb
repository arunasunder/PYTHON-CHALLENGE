# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import requests
import time
import json 

# Google Places API Key
#gkey = "AIzaSyA_Clyz3478YAUnsESNHE5dyktvvMoa-vw"

# %%
# Get random 500 cities using the city py library based on latitude ranging from 
# Longitude -180 (W) to 180 (E) and latitude -90 (S) to +90 (N)

from citipy import citipy

city = citipy.nearest_city(22.99, 120.21)



print(city)

print(city.city_name)    # Tainan, my home town

print (city.country_code)

#Get Array of longitudes stored
longitude = np.arange(-180, +180, 1)
longitude_inv = np.arange(+180, -180, 1)

latitude = np.arange(-90, +90, 0.5)
latitude_inv = np.arange(+90, -90, 0.5)

i = 0
j = 0

city_count = 0

Longitude_count = len(longitude)
latitude_count = len(latitude)

LongitudeInv_count = len(longitude_inv)
latitudeInv_count = len (latitude_inv)

max_i = Longitude_count
max_j = latitude_count

firstPass = False
k = 0
l = 0

while city_count <= 500: 
    if ( i >= Longitude_count or j >= latitude_count):
        # You have reached the max value 
        print("We reached max on first pass")
        lon = longitude_inv[k]
        lat = latitude_inv[l]
        k = k + 1
        l = l + 1
    else: 
        lon = longitude[i]
        lat = latitude[j]
        i = i + 1
        j = j + 1
    
    city = citipy.nearest_city(lat, lon)
    print ("City: %s Country Code: %s Longitude: %s Latitude: %s" %(city.city_name, city.country_code, str(lon), str(lat)))
    
    city_count = city_count + 1
# Out:
# ...
# tainan
# tw
# City: vaini Country Code: to Longitude: -180 Latitude: -90.0
# City: vaini Country Code: to Longitude: -179 Latitude: -89.5
# City: vaini Country Code: to Longitude: -178 Latitude: -89.0
# City: vaini Country Code: to Longitude: -177 Latitude: -88.5
# City: vaini Country Code: to Longitude: -176 Latitude: -88.0
# City: vaini Country Code: to Longitude: -175 Latitude: -87.5
# City: vaini Country Code: to Longitude: -174 Latitude: -87.0
# City: vaini Country Code: to Longitude: -173 Latitude: -86.5
# City: vaini Country Code: to Longitude: -172 Latitude: -86.0
# City: vaini Country Code: to Longitude: -171 Latitude: -85.5
# City: vaini Country Code: to Longitude: -170 Latitude: -85.0
# City: vaini Country Code: to Longitude: -169 Latitude: -84.5
# City: vaini Country Code: to Longitude: -168 Latitude: -84.0
# City: mataura Country Code: pf Longitude: -167 Latitude: -83.5
# City: mataura Country Code: pf Longitude: -166 Latitude: -83.0
# ...

# %%
# ?np.arange
